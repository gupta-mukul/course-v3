# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *
from google.colab import files

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise window.open() coomand doesn't work. Then you can run the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Parent Directory to store files of all classes

# %%
path = Path('data/bears')

# %% [markdown]
# #### **Black Bear**

# %% [markdown]
# Make class - "black" directory

# %%
folder = 'black'
file = 'urls_black.csv'

# %%
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Upload url file and move to bear directory

# %%
files.upload()
! mv {file} 'data/bears/'
# Out:
#      <input type="file" id="files-b159eea6-c8e9-4a1d-a73f-920c8ca6dd99" name="files[]" multiple disabled />
#      <output id="result-b159eea6-c8e9-4a1d-a73f-920c8ca6dd99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_black.csv to urls_black.csv

# %% [markdown]
# Download images

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# Verify Images

# %%
path.ls()
dest.ls()
# Out:
# [PosixPath('data/bears/black/00000080.jpg'),
#  PosixPath('data/bears/black/00000165.jpg'),
#  PosixPath('data/bears/black/00000012.jpg'),
#  PosixPath('data/bears/black/00000048.jpg'),
#  PosixPath('data/bears/black/00000148.jpg'),
#  PosixPath('data/bears/black/00000089.jpg'),
#  PosixPath('data/bears/black/00000168.jpg'),
#  PosixPath('data/bears/black/00000064.jpg'),
#  PosixPath('data/bears/black/00000095.jpg'),
#  PosixPath('data/bears/black/00000071.jpg'),
#  PosixPath('data/bears/black/00000174.jpg'),
#  PosixPath('data/bears/black/00000018.jpg'),
#  PosixPath('data/bears/black/00000102.jpg'),
#  PosixPath('data/bears/black/00000104.jpg'),
#  PosixPath('data/bears/black/00000151.jpg'),
#  PosixPath('data/bears/black/00000062.png')]

# %% [markdown]
# ###Teddy Bear

# %% [markdown]
# Make class - "teddy" directory

# %%
folder = 'teddys'
file = 'urls_teddys.csv'

# %%
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Upload url file and move to bear directory

# %%
files.upload()
! mv {file} 'data/bears/'
# Out:
#      <input type="file" id="files-013c5cea-acdd-40c2-bce2-5c4c324cd4e5" name="files[]" multiple disabled />
#      <output id="result-013c5cea-acdd-40c2-bce2-5c4c324cd4e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_teddys.csv to urls_teddys.csv

# %% [markdown]
# Download images

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# Verify Images

# %%
path.ls()
dest.ls()
# Out:
# [PosixPath('data/bears/teddys/00000080.jpg'),
#  PosixPath('data/bears/teddys/00000012.jpg'),
#  PosixPath('data/bears/teddys/00000048.jpg'),
#  PosixPath('data/bears/teddys/00000099.jpeg'),
#  PosixPath('data/bears/teddys/00000089.jpg'),
#  PosixPath('data/bears/teddys/00000064.jpg'),
#  PosixPath('data/bears/teddys/00000006.jpg'),
#  PosixPath('data/bears/teddys/00000079.jpg'),
#  PosixPath('data/bears/teddys/00000061.jpg'),
#  PosixPath('data/bears/teddys/00000070.jpeg'),
#  PosixPath('data/bears/teddys/00000051.jpg'),
#  PosixPath('data/bears/teddys/00000072.png'),
#  PosixPath('data/bears/teddys/00000086.jpg'),
#  PosixPath('data/bears/teddys/00000017.jpg'),
#  PosixPath('data/bears/teddys/00000030.jpg'),
#  PosixPath('data/bears/teddys/00000046.jpg'),
#  PosixPath('data/bears/teddys/00000041.png'),
#  PosixPath('data/bears/teddys/00000042.jpg'),
#  PosixPath('data/bears/teddys/00000024.jpg'),
#  PosixPath('data/bears/teddys/00000093.jpg'),
#  PosixPath('data/bears/teddys/00000091.jpg'),
#  PosixPath('data/bears/teddys/00000036.jpg'),
#  PosixPath('data/bears/teddys/00000067.png'),
#  PosixPath('data/bears/teddys/00000021.jpg'),
#  PosixPath('data/bears/teddys/00000025.jpg'),
#  PosixPath('data/bears/teddys/00000029.png'),
#  PosixPath('data/bears/teddys/00000010.jpg'),
#  PosixPath('data/bears/teddys/00000065.jpg'),
#  PosixPath('data/bears/teddys/00000045.jpg'),
#  PosixPath('data/bears/teddys/00000057.jpg'),
#  PosixPath('data/bears/teddys/00000060.jpg'),
#  PosixPath('data/bears/teddys/00000023.jpg'),
#  PosixPath('data/bears/teddys/00000007.jpg'),
#  PosixPath('data/bears/teddys/00000078.jpg'),
#  PosixPath('data/bears/teddys/00000001.jpg'),
#  PosixPath('data/bears/teddys/00000097.jpg'),
#  PosixPath('data/bears/teddys/00000053.jpg'),
#  PosixPath('data/bears/teddys/00000050.jpg'),
#  PosixPath('data/bears/teddys/00000032.jpg'),
#  PosixPath('data/bears/teddys/00000026.jpg'),
#  PosixPath('data/bears/teddys/00000031.jpg'),
#  PosixPath('data/bears/teddys/00000063.jpg'),
#  PosixPath('data/bears/teddys/00000088.jpg'),
#  PosixPath('data/bears/teddys/00000062.jpg'),
#  PosixPath('data/bears/teddys/00000066.jpg'),
#  PosixPath('data/bears/teddys/00000087.jpg'),
#  PosixPath('data/bears/teddys/00000003.jpg'),
#  PosixPath('data/bears/teddys/00000090.jpg'),
#  PosixPath('data/bears/teddys/00000058.jpg'),
#  PosixPath('data/bears/teddys/00000075.JPG'),
#  PosixPath('data/bears/teddys/00000008.jpg'),
#  PosixPath('data/bears/teddys/00000069.jpg'),
#  PosixPath('data/bears/teddys/00000027.jpg'),
#  PosixPath('data/bears/teddys/00000049.png'),
#  PosixPath('data/bears/teddys/00000084.jpg'),
#  PosixPath('data/bears/teddys/00000076.jpg'),
#  PosixPath('data/bears/teddys/00000034.gif'),
#  PosixPath('data/bears/teddys/00000056.jpg'),
#  PosixPath('data/bears/teddys/00000002.jpg'),
#  PosixPath('data/bears/teddys/00000000.jpg'),
#  PosixPath('data/bears/teddys/00000040.jpg'),
#  PosixPath('data/bears/teddys/00000015.jpg'),
#  PosixPath('data/bears/teddys/00000009.jpeg'),
#  PosixPath('data/bears/teddys/00000082.jpeg'),
#  PosixPath('data/bears/teddys/00000096.jpg'),
#  PosixPath('data/bears/teddys/00000047.png'),
#  PosixPath('data/bears/teddys/00000033.jpg'),
#  PosixPath('data/bears/teddys/00000039.jpg'),
#  PosixPath('data/bears/teddys/00000043.jpg'),
#  PosixPath('data/bears/teddys/00000004.jpg'),
#  PosixPath('data/bears/teddys/00000085.jpg'),
#  PosixPath('data/bears/teddys/00000016.jpg'),
#  PosixPath('data/bears/teddys/00000098.jpg'),
#  PosixPath('data/bears/teddys/00000005.jpeg'),
#  PosixPath('data/bears/teddys/00000013.jpg'),
#  PosixPath('data/bears/teddys/00000035.jpg'),
#  PosixPath('data/bears/teddys/00000081.jpg'),
#  PosixPath('data/bears/teddys/00000054.jpg'),
#  PosixPath('data/bears/teddys/00000019.jpg'),
#  PosixPath('data/bears/teddys/00000083.jpg'),
#  PosixPath('data/bears/teddys/00000077.jpg'),
#  PosixPath('data/bears/teddys/00000037.jpg'),
#  PosixPath('data/bears/teddys/00000014.jpg'),
#  PosixPath('data/bears/teddys/00000044.jpg'),
#  PosixPath('data/bears/teddys/00000059.jpg'),
#  PosixPath('data/bears/teddys/00000073.jpg'),
#  PosixPath('data/bears/teddys/00000092.jpg'),
#  PosixPath('data/bears/teddys/00000068.jpg'),
#  PosixPath('data/bears/teddys/00000028.jpg'),
#  PosixPath('data/bears/teddys/00000055.jpg'),
#  PosixPath('data/bears/teddys/00000038.jpg'),
#  PosixPath('data/bears/teddys/00000052.jpg'),
#  PosixPath('data/bears/teddys/00000011.jpg'),
#  PosixPath('data/bears/teddys/00000094.jpg'),
#  PosixPath('data/bears/teddys/00000020.jpeg'),
#  PosixPath('data/bears/teddys/00000022.jpg'),
#  PosixPath('data/bears/teddys/00000095.jpg'),
#  PosixPath('data/bears/teddys/00000071.jpg'),
#  PosixPath('data/bears/teddys/00000018.jpg')]

# %% [markdown]
# ###Grizzly Bear

# %% [markdown]
# Make class - "grizzly" directory

# %%
folder = 'grizzly'
file = 'urls_grizzly.csv'

# %%
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Upload url file and move to bear directory

# %%
files.upload()
! mv {file} 'data/bears/'
# Out:
#      <input type="file" id="files-270e0e1b-86c8-402c-b942-3b06de9308e7" name="files[]" multiple disabled />
#      <output id="result-270e0e1b-86c8-402c-b942-3b06de9308e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_grizzly.csv to urls_grizzly.csv

# %% [markdown]
# Download images

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# Verify Images

# %%
path.ls()
dest.ls()
# Out:
# [PosixPath('data/bears/grizzly/00000080.jpg'),
#  PosixPath('data/bears/grizzly/00000012.jpg'),
#  PosixPath('data/bears/grizzly/00000048.jpg'),
#  PosixPath('data/bears/grizzly/00000089.jpg'),
#  PosixPath('data/bears/grizzly/00000064.jpg'),
#  PosixPath('data/bears/grizzly/00000006.jpg'),
#  PosixPath('data/bears/grizzly/00000020.jpg'),
#  PosixPath('data/bears/grizzly/00000050.jpeg'),
#  PosixPath('data/bears/grizzly/00000079.jpg'),
#  PosixPath('data/bears/grizzly/00000061.jpg'),
#  PosixPath('data/bears/grizzly/00000051.jpg'),
#  PosixPath('data/bears/grizzly/00000075.jpg'),
#  PosixPath('data/bears/grizzly/00000086.jpg'),
#  PosixPath('data/bears/grizzly/00000017.jpg'),
#  PosixPath('data/bears/grizzly/00000030.jpg'),
#  PosixPath('data/bears/grizzly/00000046.jpg'),
#  PosixPath('data/bears/grizzly/00000042.jpg'),
#  PosixPath('data/bears/grizzly/00000024.jpg'),
#  PosixPath('data/bears/grizzly/00000093.jpg'),
#  PosixPath('data/bears/grizzly/00000091.jpg'),
#  PosixPath('data/bears/grizzly/00000036.jpg'),
#  PosixPath('data/bears/grizzly/00000021.jpg'),
#  PosixPath('data/bears/grizzly/00000025.jpg'),
#  PosixPath('data/bears/grizzly/00000005.jpg'),
#  PosixPath('data/bears/grizzly/00000049.jpg'),
#  PosixPath('data/bears/grizzly/00000010.jpg'),
#  PosixPath('data/bears/grizzly/00000065.jpg'),
#  PosixPath('data/bears/grizzly/00000045.jpg'),
#  PosixPath('data/bears/grizzly/00000084.jpeg'),
#  PosixPath('data/bears/grizzly/00000057.jpg'),
#  PosixPath('data/bears/grizzly/00000060.jpg'),
#  PosixPath('data/bears/grizzly/00000072.jpg'),
#  PosixPath('data/bears/grizzly/00000023.jpg'),
#  PosixPath('data/bears/grizzly/00000007.jpg'),
#  PosixPath('data/bears/grizzly/00000078.jpg'),
#  PosixPath('data/bears/grizzly/00000099.jpg'),
#  PosixPath('data/bears/grizzly/00000097.jpg'),
#  PosixPath('data/bears/grizzly/00000053.jpg'),
#  PosixPath('data/bears/grizzly/00000032.jpg'),
#  PosixPath('data/bears/grizzly/00000026.jpg'),
#  PosixPath('data/bears/grizzly/00000031.jpg'),
#  PosixPath('data/bears/grizzly/00000063.jpg'),
#  PosixPath('data/bears/grizzly/00000088.jpg'),
#  PosixPath('data/bears/grizzly/00000062.jpg'),
#  PosixPath('data/bears/grizzly/00000066.jpg'),
#  PosixPath('data/bears/grizzly/00000087.jpg'),
#  PosixPath('data/bears/grizzly/00000003.jpg'),
#  PosixPath('data/bears/grizzly/00000090.jpg'),
#  PosixPath('data/bears/grizzly/00000058.jpg'),
#  PosixPath('data/bears/grizzly/00000001.png'),
#  PosixPath('data/bears/grizzly/00000008.jpg'),
#  PosixPath('data/bears/grizzly/00000069.jpg'),
#  PosixPath('data/bears/grizzly/00000027.jpg'),
#  PosixPath('data/bears/grizzly/00000047.jpg'),
#  PosixPath('data/bears/grizzly/00000076.jpg'),
#  PosixPath('data/bears/grizzly/00000056.jpg'),
#  PosixPath('data/bears/grizzly/00000009.jpg'),
#  PosixPath('data/bears/grizzly/00000070.jpg'),
#  PosixPath('data/bears/grizzly/00000002.jpg'),
#  PosixPath('data/bears/grizzly/00000029.jpg'),
#  PosixPath('data/bears/grizzly/00000040.jpg'),
#  PosixPath('data/bears/grizzly/00000015.jpg'),
#  PosixPath('data/bears/grizzly/00000083.jpeg'),
#  PosixPath('data/bears/grizzly/00000096.jpg'),
#  PosixPath('data/bears/grizzly/00000034.jpg'),
#  PosixPath('data/bears/grizzly/00000074.jpg'),
#  PosixPath('data/bears/grizzly/00000041.jpeg'),
#  PosixPath('data/bears/grizzly/00000033.jpg'),
#  PosixPath('data/bears/grizzly/00000039.jpg'),
#  PosixPath('data/bears/grizzly/00000043.jpg'),
#  PosixPath('data/bears/grizzly/00000004.jpg'),
#  PosixPath('data/bears/grizzly/00000085.jpg'),
#  PosixPath('data/bears/grizzly/00000016.jpg'),
#  PosixPath('data/bears/grizzly/00000098.jpg'),
#  PosixPath('data/bears/grizzly/00000000.ashx'),
#  PosixPath('data/bears/grizzly/00000013.jpg'),
#  PosixPath('data/bears/grizzly/00000035.jpg'),
#  PosixPath('data/bears/grizzly/00000081.jpg'),
#  PosixPath('data/bears/grizzly/00000011.JPG'),
#  PosixPath('data/bears/grizzly/00000054.jpg'),
#  PosixPath('data/bears/grizzly/00000019.jpg'),
#  PosixPath('data/bears/grizzly/00000067.jpg'),
#  PosixPath('data/bears/grizzly/00000077.jpg'),
#  PosixPath('data/bears/grizzly/00000037.jpg'),
#  PosixPath('data/bears/grizzly/00000014.jpg'),
#  PosixPath('data/bears/grizzly/00000044.jpg'),
#  PosixPath('data/bears/grizzly/00000082.png'),
#  PosixPath('data/bears/grizzly/00000059.jpg'),
#  PosixPath('data/bears/grizzly/00000073.jpg'),
#  PosixPath('data/bears/grizzly/00000092.jpg'),
#  PosixPath('data/bears/grizzly/00000068.jpg'),
#  PosixPath('data/bears/grizzly/00000028.jpg'),
#  PosixPath('data/bears/grizzly/00000055.jpg'),
#  PosixPath('data/bears/grizzly/00000038.jpg'),
#  PosixPath('data/bears/grizzly/00000052.jpg'),
#  PosixPath('data/bears/grizzly/00000094.jpg'),
#  PosixPath('data/bears/grizzly/00000022.jpg'),
#  PosixPath('data/bears/grizzly/00000095.jpg'),
#  PosixPath('data/bears/grizzly/00000071.jpg'),
#  PosixPath('data/bears/grizzly/00000018.jpg')]

# %% [markdown]
# ## Clean images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['teddys','grizzly','black']

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %% [markdown]
# List remaining files

# %%
for c in classes:
  class_dir=path/c
  print(class_dir.ls())
# Out:
# [PosixPath('data/bears/teddys/00000080.jpg'), PosixPath('data/bears/teddys/00000012.jpg'), PosixPath('data/bears/teddys/00000048.jpg'), PosixPath('data/bears/teddys/00000099.jpeg'), PosixPath('data/bears/teddys/00000089.jpg'), PosixPath('data/bears/teddys/00000064.jpg'), PosixPath('data/bears/teddys/00000006.jpg'), PosixPath('data/bears/teddys/00000079.jpg'), PosixPath('data/bears/teddys/00000061.jpg'), PosixPath('data/bears/teddys/00000070.jpeg'), PosixPath('data/bears/teddys/00000051.jpg'), PosixPath('data/bears/teddys/00000072.png'), PosixPath('data/bears/teddys/00000086.jpg'), PosixPath('data/bears/teddys/00000017.jpg'), PosixPath('data/bears/teddys/00000030.jpg'), PosixPath('data/bears/teddys/00000046.jpg'), PosixPath('data/bears/teddys/00000041.png'), PosixPath('data/bears/teddys/00000042.jpg'), PosixPath('data/bears/teddys/00000024.jpg'), PosixPath('data/bears/teddys/00000093.jpg'), PosixPath('data/bears/teddys/00000091.jpg'), PosixPath('data/bears/teddys/00000036.jpg'), PosixPath('data/bears/teddys/00000067.png'), PosixPath('data/bears/teddys/00000025.jpg'), PosixPath('data/bears/teddys/00000029.png'), PosixPath('data/bears/teddys/00000010.jpg'), PosixPath('data/bears/teddys/00000065.jpg'), PosixPath('data/bears/teddys/00000045.jpg'), PosixPath('data/bears/teddys/00000057.jpg'), PosixPath('data/bears/teddys/00000060.jpg'), PosixPath('data/bears/teddys/00000023.jpg'), PosixPath('data/bears/teddys/00000007.jpg'), PosixPath('data/bears/teddys/00000078.jpg'), PosixPath('data/bears/teddys/00000001.jpg'), PosixPath('data/bears/teddys/00000097.jpg'), PosixPath('data/bears/teddys/00000053.jpg'), PosixPath('data/bears/teddys/00000050.jpg'), PosixPath('data/bears/teddys/00000032.jpg'), PosixPath('data/bears/teddys/00000026.jpg'), PosixPath('data/bears/teddys/00000031.jpg'), PosixPath('data/bears/teddys/00000063.jpg'), PosixPath('data/bears/teddys/00000088.
/bears/black/00000072.jpg'), PosixPath('data/bears/black/00000023.jpg'), PosixPath('data/bears/black/00000007.jpg'), PosixPath('data/bears/black/00000146.jpg'), PosixPath('data/bears/black/00000131.png'), PosixPath('data/bears/black/00000179.jpg'), PosixPath('data/bears/black/00000112.jpg'), PosixPath('data/bears/black/00000001.jpg'), PosixPath('data/bears/black/00000099.jpg'), PosixPath('data/bears/black/00000097.jpg'), PosixPath('data/bears/black/00000053.jpg'), PosixPath('data/bears/black/00000032.jpg'), PosixPath('data/bears/black/00000185.png'), PosixPath('data/bears/black/00000030.JPG'), PosixPath('data/bears/black/00000175.jpg'), PosixPath('data/bears/black/00000026.jpg'), PosixPath('data/bears/black/00000103.JPG'), PosixPath('data/bears/black/00000125.jpg'), PosixPath('data/bears/black/00000134.jpg'), PosixPath('data/bears/black/00000031.jpg'), PosixPath('data/bears/black/00000063.jpg'), PosixPath('data/bears/black/00000197.jpg'), PosixPath('data/bears/black/00000066.jpg'), PosixPath('data/bears/black/00000087.jpg'), PosixPath('data/bears/black/00000130.jpg'), PosixPath('data/bears/black/00000003.jpg'), PosixPath('data/bears/black/00000058.jpg'), PosixPath('data/bears/black/00000149.jpg'), PosixPath('data/bears/black/00000141.jpg'), PosixPath('data/bears/black/00000082.jpg'), PosixPath('data/bears/black/00000078.png'), PosixPath('data/bears/black/00000184.j ...

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 292, 72)

# %% [markdown]
# ## Train model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:01<00:00, 57599967.23it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.197010</td>
#       <td>0.241069</td>
#       <td>0.041667</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.663926</td>
#       <td>0.035818</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.449722</td>
#       <td>0.015748</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.330243</td>
#       <td>0.014820</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# If the plot is not showing try to give a start and end learning rate# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035527</td>
#       <td>0.033712</td>
#       <td>0.013889</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.027693</td>
#       <td>0.037324</td>
#       <td>0.013889</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .no_split()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.# If you do run this on Jupyter Lab, you need to restart your runtime and# runtime state including all local variables will be lost.ImageCleaner(ds, idxs, path)
# Out:
# 'No images to show :)'

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, loosing all the results from cleaning the data from toplosses.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 00:03<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# **bold text**## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 380, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>13.138073</td>
#       <td>73162744.000000</td>
#       <td>0.680556</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.280962</td>
#       <td>1.533961</td>
#       <td>0.777778</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.276055</td>
#       <td>1.297661</td>
#       <td>0.736111</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.258619</td>
#       <td>1.177293</td>
#       <td>0.652778</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.261844</td>
#       <td>1.120199</td>
#       <td>0.625000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.251997</td>
#       <td>1.092004</td>
#       <td>0.569444</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.260482</td>
#       <td>3.694569</td>
#       <td>0.791667</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###